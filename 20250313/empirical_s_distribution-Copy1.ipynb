# %%
import numpy as np
import scipy.stats as ss
import matplotlib.pyplot as plt

# %%
def rs(n_samp, n):
    return [sum([ss.norm.rvs() for _ in range(n)])  for _ in range(n_samp)]

# %%
brvs = rs(10000, 1)
mfact = 10
brvs_more = rs(10000, mfact)

# %%
plt.hist(brvs, bins=100, alpha=0.3, density=True, label="N=1");
plt.hist(brvs_more, bins=100, alpha=0.3, density=True, label="N=" + str(mfact));
xs = np.linspace(-10, 10, 1000)
plt.plot(xs, 1.0/np.sqrt(2*np.pi) * np.exp(-0.5 * xs**2))
plt.plot(xs, 1.0/np.sqrt(2*np.pi) / np.sqrt(mfact) * np.exp(-0.5 * xs**2 / 10))
plt.legend()
