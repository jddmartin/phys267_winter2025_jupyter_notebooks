# %%
import matplotlib.pyplot as plt
import math
import numpy as np

# %%
 math.factorial(2)
# Out:
# 2

# %%
ks = list(range(100))
mu = 10
fs = [mu**k / math.factorial(k) * np.exp(-mu) for k in ks]

# %%
plt.bar(ks, fs)
ax = plt.gca()
ax.set_xlim([0,20])
# Out:
# (0.0, 20.0)
