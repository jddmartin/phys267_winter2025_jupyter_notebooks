# %%
import matplotlib.pyplot as plt
import math
import numpy as np

# %%
 math.factorial(2)
# Out:
# 2

# %%
ks = list(range(100))
mu = 10
fs = [mu**k / math.factorial(k) * np.exp(-mu) for k in ks]
fs
# Out:
# [4.5399929762484854e-05,
#  0.00045399929762484856,
#  0.0022699964881242427,
#  0.007566654960414142,
#  0.018916637401035358,
#  0.037833274802070715,
#  0.06305545800345119,
#  0.09007922571921598,
#  0.11259903214901998,
#  0.1251100357211333,
#  0.1251100357211333,
#  0.1137363961101212,
#  0.09478033009176765,
#  0.07290794622443666,
#  0.05207710444602618,
#  0.03471806963068413,
#  0.021698793519177577,
#  0.012763996187751515,
#  0.007091108993195287,
#  0.0037321626279975197,
#  0.0018660813139987598,
#  0.000888610149523219,
#  0.00040391370432873584,
#  0.0001756146540559721,
#  7.317277252332172e-05,
#  2.9269109009328688e-05,
#  1.125734961897257e-05,
#  4.169388747767619e-06,
#  1.4890674099170067e-06,
#  5.134715206610369e-07,
#  1.7115717355367894e-07,
#  5.521199146892869e-08,
#  1.7253747334040217e-08,
#  5.228408283042489e-09,
#  1.5377671420713203e-09,
#  4.3936204059180586e-10,
#  1.2204501127550163e-10,
#  3.298513818256801e-11,
#  8.680299521728422e-12,
# ...

# %%
plt.bar(ks, fs)
ax = plt.gca()
ax.set_xlim([0,20])
# Out:
# (0.0, 20.0)
